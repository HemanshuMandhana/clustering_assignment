# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.cluster import KMeans, MeanShift, estimate_bandwidth, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
import warnings
warnings.filterwarnings("ignore")

# Load dataset
iris = datasets.load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)

# Preprocessing
def preprocess_data(X, method):
    if method == "none":
        return X
    elif method == "normalize":
        return MinMaxScaler().fit_transform(X)
    elif method == "standardize":
        return StandardScaler().fit_transform(X)
    elif method == "pca":
        return PCA(n_components=2).fit_transform(StandardScaler().fit_transform(X))
    elif method == "t+n":
        X_t = np.log1p(X)
        return MinMaxScaler().fit_transform(X_t)
    elif method == "t+n+pca":
        X_t = np.log1p(X)
        X_n = MinMaxScaler().fit_transform(X_t)
        return PCA(n_components=2).fit_transform(X_n)

# Evaluation metrics
def evaluate_clustering(X, labels):
    return {
        "Silhouette": silhouette_score(X, labels),
        "Calinski-Harabasz": calinski_harabasz_score(X, labels),
        "Davies-Bouldin": davies_bouldin_score(X, labels)
    }

# Parameters
cluster_range = [3, 4, 5]
preprocess_methods = ["none", "normalize", "standardize", "pca", "t+n", "t+n+pca"]

# Collect results
results = []

# KMeans
for prep in preprocess_methods:
    X_prep = preprocess_data(X, prep)
    for c in cluster_range:
        try:
            kmeans = KMeans(n_clusters=c, n_init=10, random_state=42)
            labels = kmeans.fit_predict(X_prep)
            scores = evaluate_clustering(X_prep, labels)
            results.append({"Method": "KMeans", "Preprocessing": prep, "Clusters": c, **scores})
        except:
            results.append({"Method": "KMeans", "Preprocessing": prep, "Clusters": c,
                            "Silhouette": np.nan, "Calinski-Harabasz": np.nan, "Davies-Bouldin": np.nan})

# Hierarchical
for prep in preprocess_methods:
    X_prep = preprocess_data(X, prep)
    for c in cluster_range:
        try:
            hc = AgglomerativeClustering(n_clusters=c)
            labels = hc.fit_predict(X_prep)
            scores = evaluate_clustering(X_prep, labels)
            results.append({"Method": "Hierarchical", "Preprocessing": prep, "Clusters": c, **scores})
        except:
            results.append({"Method": "Hierarchical", "Preprocessing": prep, "Clusters": c,
                            "Silhouette": np.nan, "Calinski-Harabasz": np.nan, "Davies-Bouldin": np.nan})

# MeanShift
for prep in preprocess_methods:
    X_prep = preprocess_data(X, prep)
    try:
        bandwidth = estimate_bandwidth(X_prep, quantile=0.2)
        if bandwidth <= 0:
            bandwidth = 1  # fallback
        ms = MeanShift(bandwidth=bandwidth, bin_seeding=True)
        labels = ms.fit_predict(X_prep)
        n_clusters_ = len(np.unique(labels))
        scores = evaluate_clustering(X_prep, labels)
        for c in cluster_range:
            if c == n_clusters_:
                results.append({"Method": "MeanShift", "Preprocessing": prep, "Clusters": c, **scores})
            else:
                results.append({"Method": "MeanShift", "Preprocessing": prep, "Clusters": c,
                                "Silhouette": np.nan, "Calinski-Harabasz": np.nan, "Davies-Bouldin": np.nan})
    except:
        for c in cluster_range:
            results.append({"Method": "MeanShift", "Preprocessing": prep, "Clusters": c,
                            "Silhouette": np.nan, "Calinski-Harabasz": np.nan, "Davies-Bouldin": np.nan})

# Final DataFrame
df_final = pd.DataFrame(results)
pd.set_option("display.precision", 3)
df_final_styled = df_final.style.background_gradient(cmap='coolwarm',
    subset=["Silhouette", "Calinski-Harabasz", "Davies-Bouldin"])

# Show
df_final_styled
# Out:
# <style type="text/css">
# #T_9161b_row0_col3 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_9161b_row0_col4 {
#   background-color: #c0282f;
#   color: #f1f1f1;
# }
# #T_9161b_row0_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_9161b_row1_col3 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_9161b_row1_col4 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_9161b_row1_col5, #T_9161b_row17_col5 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_9161b_row2_col3, #T_9161b_row13_col5, #T_9161b_row19_col3 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_9161b_row2_col4 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_9161b_row2_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_9161b_row3_col3, #T_9161b_row20_col4, #T_9161b_row21_col3 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_9161b_row3_col4 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_9161b_row3_col5, #T_9161b_row39_col5 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_9161b_row4_col3 {
#   background-color: #e6d7cf;
#   color: #000000;
# }
# #T_9161b_row4_col4, #T_9161b_row29_col3 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_9161b_row4_col5 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_9161b_row5_col3, #T_9161b_row18_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_9161b_row5_col4, #T_9161b_row39_col4 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_9161b_row5_col5 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_9161b_row6_col3 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_9161b_row6_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_9161b_row6_col5 {
#   background-color: #ebd3c6;
#   color: #000000;
# }
# #T_9161b_row7_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_9161b_row7_col4 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_9161b_row7_col5 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_9161b_row8_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_9161b_row8_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_9161b_row8_col5, #T_9161b_row16_col4 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_9161b_row9_col3 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_9161b_row9_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_9161b_row9_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_9161b_row10_col3 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_9161b_row10_col4 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_9161b_row10_col5 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_9161b_row11_col3, #T_9161b_row30_col5 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_9161b_row11_col4, #T_9161b_row48_col4 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_9161b_row11_col5 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_9161b_row12_col3, #T_9161b_row23_col5 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_9161b_row12_col4, #T_9161b_row39_col3 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_9161b_row12_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_9161b_row13_col3, #T_9161b_row42_col5 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_9161b_row13_col4, #T_9161b_row24_col5 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_9161b_row14_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_9161b_row14_col4 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_9161b_row14_col5, #T_9161b_row15_col4, #T_9161b_row18_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_9161b_row15_col3 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_9161b_row15_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_9161b_row16_col3, #T_9161b_row19_col4 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_9161b_row16_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_9161b_row17_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_9161b_row17_col4 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_9161b_row18_col4, #T_9161b_row48_col3 {
#   background-color: #c32e31;
#   color: #f1f1f1;
# }
# #T_9161b_row19_col5 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_9161b_row20_col3 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_9161b_row20_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_9161b_row21_col4 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_9161b_row21_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_9161b_row22_col3, #T_9161b_row42_col3 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_9161b_row22_col4 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_9161b_row22_col5 {
#   background-color: #f1ccb8;
#   color: #000000;
# }
# #T_9161b_row23_col3 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_9161b_row23_col4, #T_9161b_row27_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_9161b_row24_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_9161b_row24_col4 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_9161b_row25_col3 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_9161b_row25_col4 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_9161b_row25_col5 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_9161b_row26_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_9161b_row26_col4, #T_9161b_row34_col5 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_9161b_row26_col5 {
#   background-color: #d95847;
#   color: #f1f1f1;
# }
# #T_9161b_row27_col3 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_9161b_row27_col4 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_9161b_row28_col3 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_9161b_row28_col4, #T_9161b_row29_col4 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_9161b_row28_col5, #T_9161b_row35_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_9161b_row29_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_9161b_row30_col3 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_9161b_row30_col4 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_9161b_row31_col3 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_9161b_row31_col4, #T_9161b_row52_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_9161b_row31_col5 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_9161b_row32_col3, #T_9161b_row33_col5, #T_9161b_row42_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_9161b_row32_col4 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_9161b_row32_col5 {
#   background-color: #c43032;
#   color: #f1f1f1;
# }
# #T_9161b_row33_col3 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_9161b_row33_col4 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_9161b_row34_col3 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_9161b_row34_col4 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_9161b_row35_col3 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_9161b_row35_col4 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_9161b_row36_col3, #T_9161b_row36_col4, #T_9161b_row36_col5, #T_9161b_row37_col3, #T_9161b_row37_col4, #T_9161b_row37_col5, #T_9161b_row38_col3, #T_9161b_row38_col4, #T_9161b_row38_col5, #T_9161b_row40_col3, #T_9161b_row40_col4, #T_9161b_row40_col5, #T_9161b_row41_col3, #T_9161b_row41_col4, #T_9161b_row41_col5, #T_9161b_row43_col3, #T_9161b_row43_col4, #T_9161b_row43_col5, #T_9161b_row44_col3, #T_9161b_row44_col4, #T_9161b_row44_col5, #T_9161b_row46_col3, #T_9161b_row46_col4, #T_9161b_row46_col5, #T_9161b_row47_col3, #T_9161b_row47_col4, #T_9161b_row47_col5, #T_9161b_row49_col3, #T_9161b_row49_col4, #T_9161b_row49_col5, #T_9161b_row50_col3, #T_9161b_row50_col4, #T_9161b_row50_col5, #T_9161b_row51_col3, #T_9161b_row51_col4, #T_9161b_row51_col5, #T_9161b_row53_col3, #T_9161b_row53_col4, #T_9161b_row53_col5 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9161b_row45_col3 {
#   background-color: #f7a98b;
#   color: #000000;
# }
# #T_9161b_row45_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_9161b_row45_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_9161b_row48_co
